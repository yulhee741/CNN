# %%
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt

# %%
img = load_img('./galtan.jpg')
img_w, img_h = 400, 400

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=703x468 at 0x7FA80E643880>

# %%
data = img_to_array(img)
data
# Out:
# array([[[255., 255., 255.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [254., 254., 254.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [254., 254., 254.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [254., 254., 254.],
#         [255., 255., 255.]],
#
#        ...,
#
#        [[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [253., 253., 253.],
#         [253., 253., 253.],
#         [252., 252., 252.]],
#
#        [[254., 254., 254.],
#         [253., 253., 253.],
#         [254., 254., 254.],
#         ...,
#         [253., 253., 253.],
#         [253., 253., 253.],
#         [252., 252., 252.]],
#
#        [[254., 254., 254.],
#         [253., 253., 253.],
#         [254., 254., 254.],
#         ...,
#         [252., 252., 252.],
#         [252., 252., 252.],
#         [253., 253., 253.]]], dtype=float32)

# %%
samples = expand_dims(data, 0)

# %%
datagen = ImageDataGenerator(
                            zoom_range=[0.5,1.0],
                            rotation_range=90,
                            horizontal_flip=True,
                            vertical_flip=True,
                            height_shift_range=0.3,
                            width_shift_range=0.3 )

iter = datagen.flow(samples, batch_size=1)

# %%
fig = plt.figure(figsize = (20,20))

for i in range(12):
    plt.subplot(4, 3, 1 + i)
    batch = iter.next()
    image = batch[0].astype('uint8')
    plt.imshow(image)
    
plt.show()
